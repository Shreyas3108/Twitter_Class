# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Shreyas3108/Twitter_Class/blob/master/TweetsExtraction.ipynb)

# %%
# !pip install tweepy
# Out:
# ...
#     100% |████████████████████████████████| 286kB 6.4MB/s
# ...
# done
#   Stored in directory: /content/.cache/pip/wheels/22/5c/b5/12e0dfdfa85bea67b23628b6425fae715c687e947a45ee3df9
# Successfully built PySocks
# ...

# %%
# !pip install TextBlob
# Out:
# ...
#     100% |████████████████████████████████| 634kB 5.3MB/s
# ...

# %%
import tweepy 
import textblob

# %%
from textblob import TextBlob

# %%
# Authentication Consumer Key's

consumer_key = '' 

consumer_secret = ''

# %%
# Authentication Access Tokens 

access_token = ''

access_token_secret = ''

# %%
oauth = tweepy.OAuthHandler(consumer_key , consumer_secret)

# %%
b = tweepy.OAuthHandler('134' , '213')

# %%
oauth.set_access_token(access_token , access_token_secret)

# %%
api = tweepy.API(oauth)

# %%
public_tweets = api.search("#KKRvsCSK")

# %%
new_tweets = api.user_timeline(screen_name = '@ChelseaFC',count=200)

# %%
for tweet in public_tweets:
  print(tweet.text)
  
  analyse = TextBlob(tweet.text)
  
  print(analyse.sentiment)
  
  print("--------------")
# Out:
# RT @SirIshantSharma: I Was Alive When Best Fielder And Legend Almighty @SirJadeja Dropped 2 Catches In 2 Consecutive Balls. I Have Now Seen…
# Sentiment(polarity=0.55, subjectivity=0.35)
# --------------
# RT @CricketNDTV: #IPL2018: WICKET! KM Asif dismisses Robin Uthappa for 6 runs. KKR 40/2, need 138 to win in 94 balls vs CSK
#
# #KKRvCSK #KKRv…
# Sentiment(polarity=0.8, subjectivity=0.4)
# --------------
# RT @SirJadeja: Fan Comes Down To Touch MS Dhoni's Feet. Just Another Moment For MS Dhoni. He Might Be Used To It. Happened Umpteen Number O…
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# --------------
# RT @CricketNDTV: #IPL2018: WICKET! KM Asif dismisses Robin Uthappa for 6 runs. KKR 40/2, need 138 to win in 94 balls vs CSK
#
# #KKRvCSK #KKRv…
# Sentiment(polarity=0.8, subjectivity=0.4)
# --------------
# RT @SirJadeja: I Feel Terribly Bad For MS Dhoni Haters. Every Match They Expect Him To Fail Like A Failure They Are, And Everytime He Ends-…
# ...

# %%
for tweet in new_tweets:
  print(tweet.text)
  
  analyse = TextBlob(tweet.text)
  
  print(analyse.sentiment)
  
  print("--------------")
# Out:
# Our Legends team is taking shape... 👊 #LegendsReturn
#
# https://t.co/2ZdFypYFen
# Sentiment(polarity=0.0, subjectivity=0.0)
# --------------
# Guess who's returning to Stamford Bridge! 👀🙌
#
# @MichaelEssien AND @JulianoBelletti will feature for our Legends when… https://t.co/fHqt9weRgP
# Sentiment(polarity=0.0, subjectivity=0.0)
# --------------
# 🙋‍♂️🏆 https://t.co/CJuN3Qrnqp
# Sentiment(polarity=0.0, subjectivity=0.0)
# --------------
# 🏆 The Blues beat Crystal Palace 1-0 on this day to secure the 2014-15 @PremierLeague title! https://t.co/zl1bioFs9L
# Sentiment(polarity=0.5, subjectivity=0.6)
# --------------
# Liverpool at the Bridge in 3️⃣ days...
#
# #ThrowbackThursday to a landmark goal for JT in 2015! 👏 https://t.co/u4raCyH1Tr
# Sentiment(polarity=0.0, subjectivity=0.0)
# --------------
# 📺 Head to @Dugout to watch all the best bits at Chelsea from the last month!
#
#  👉 https://t.co/soBCyXBSS2 https://t.co/s6MgF05oRl
# ...
